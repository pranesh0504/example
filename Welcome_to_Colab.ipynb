# %% [markdown]
# <a href="https://colab.research.google.com/github/pranesh0504/example/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Multiple linear Regression
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv("/content/house_price_prediction_1000.csv")
x=data[['Area','Bedrooms','Age']]
y=data['Price']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
predictions=model.predict(x_test)

# %%
print("Actual Price:",list(y_test))
print("Predicted price:",predictions)
print("Intercept:",model.intercept_)
print("Coefficients:",model.coef_)
# Out:
# Actual Price: [107.18, 133.98, 130.47, 39.25, 154.38, 65.21, 205.78, 182.7, 125.95, 152.41, 60.19, 181.57, 64.59, 163.91, 177.36, 107.8, 128.05, 143.97, 166.22, 103.92, 181.28, 94.06, 86.48, 100.37, 191.94, 188.34, 173.89, 53.95, 165.25, 84.31, 61.26, 167.41, 71.38, 53.21, 110.89, 41.89, 176.18, 195.87, 87.19, 182.06, 171.88, 83.88, 108.15, 80.81, 207.02, 61.98, 92.6, 188.24, 112.67, 155.22, 146.98, 190.89, 125.23, 115.51, 168.33, 185.3, 106.99, 53.26, 105.5, 54.19, 141.84, 56.25, 99.39, 74.02, 49.23, 97.9, 184.22, 111.16, 153.4, 200.44, 121.59, 194.52, 168.59, 179.92, 130.44, 161.83, 162.7, 133.32, 119.41, 83.47, 108.28, 51.23, 129.74, 84.76, 45.58, 66.91, 163.54, 84.43, 38.61, 43.43, 100.36, 102.69, 175.87, 160.07, 56.77, 186.12, 158.31, 67.6, 62.17, 168.67, 177.32, 136.28, 61.91, 136.11, 71.38, 107.77, 89.66, 135.74, 171.05, 99.89, 66.51, 134.12, 161.99, 159.47, 168.86, 100.8, 50.41, 182.87, 184.76, 164.8, 94.5, 117.0, 122.58, 87.39, 133.06, 151.25, 93.62, 94.28, 62.02, 181.72, 19
# ...

# %%
score=model.score(x_test,y_test)
print("R2 Score:",score)
# Out:
# R2 Score: 0.9954762140380368

# %%
new_house=[[2400,4,3]]
price=model.predict(new_house)
print("Predicted Price For new house:",price[0],"Lakhs")
# Out:
# Predicted Price For new house: 134.09771812053253 Lakhs
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Simple linear Regression
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score

# %%
data={"Area":[1000,1200,1400,1600,1800],
      "Price":[45,52,60,67,75]}
df=pd.DataFrame(data)
print("HOUSE PRICE DATASET")
print(df)
# Out:
# HOUSE PRICE DATASET
#    Area  Price
# 0  1000     45
# 1  1200     52
# 2  1400     60
# 3  1600     67
# 4  1800     75

# %%
x=df[['Area']]
y=df['Price']
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()
